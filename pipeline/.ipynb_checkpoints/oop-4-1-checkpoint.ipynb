# %% [markdown]
# # Объектно-ориентированное программирование

# %%
from pipeline1.pipeline1 import Pipeline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pipeline1.pipeline1 import Pipeline
#
# File ~\Desktop\Учеба\4-lesson\pipeline1\pipeline1.py:1
# ----> 1 from pipeline1.clean1 import Clean
#       2 from pipeline1.features1 import Features
#       3 from pipeline1.training1 import Training
#
# ModuleNotFoundError: No module named 'pipeline1.clean1'; 'pipeline1' is not a package

# %%
p = Pipeline(
    path='train.csv',
    target_name='Survived',
    #encoding_method='one-hot'
    )

# %%
p.clean()
# Out:
# Shape of dataset: (891, 12)
#
# Removing duplicates...
# 0 - strings was filtered
#
# Separating features by type...
# numeric_features: 7
# object_features: 5
# bool_features: 0
#
# Removing features with high mutual correlation...
# removed futures with high correlation: set()
# Shape of dataset: (891, 12)
#
# Preprocessing encoding object features...
# data types in the dataset: [dtype('int64') dtype('float64') dtype('bool')]
#
# Splitting dataset into training, testing and validation...
# Shape of:
# X_train: (623, 1730), X_val_test: (268, 1730)
# X_val: (187, 1730), X_test: (81, 1730)
#
# Processing nan value by k-nearest neighbors method...
# number of nan values in dataset: 0

# %%
p.features()
# Out:
# Shape of X: (623, 1730)
#
# Processing features selection based on the population stability index PSI...
# 1254 - feature was filtered
#
# Shape of X: (623, 476)
#
# Processing features selection by their importance...
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 239, number of negative: 384
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000091 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 421
# [LightGBM] [Info] Number of data points in the train set: 623, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.383628 -> initscore=-0.474179
# [LightGBM] [Info] Start training from score -0.474179
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
p.training()
# Out:
# Processing training model and hyperparameter selection...
# starting ROC-AUC:
# train: 0.9998910390516039
# val: 0.8303140096618359
# test: 0.7793548387096774
#
# Best Parameters: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 5, 'num_leaves': 5}
#
# finishing ROC-AUC:
# train: 0.8549566335425385
# val: 0.8594806763285024
# test: 0.7906451612903227
#
# Processing of saving the model...
# path: model_LGBMClassifier.pkl
#
# Processing of saving the features...
# path: features_model_LGBMClassifier.csv

# %%
from pipeline1.pipeline1 import Clean, Features, Training

# %%
c = Clean(
    path='train1.csv',
    target_name='Survived',
    encoding_method='one-hot'
    )

# %%
c.clean_dataset()
# Out:
# Shape of dataset: (891, 11)
#
# Removing duplicates...
# 0 - strings was filtered
#
# Separating features by type...
# numeric_features: 7
# object_features: 3
# bool_features: 1
#
# Removing features with high mutual correlation...
# removed futures with high correlation: set()
# Shape of dataset: (891, 11)
#
# Preprocessing encoding object features...
# data types in the dataset: [dtype('int64') dtype('float64') dtype('bool')]
#
# Splitting dataset into training, testing and validation...
# Shape of:
# X_train: (623, 29), X_val_test: (268, 29)
# X_val: (187, 29), X_test: (81, 29)
#
# Processing nan value by k-nearest neighbors method...
# number of nan values in dataset: 0

# %%
f = Features(c.X_train, c.X_val, c.X_test, c.y_train, c.y_val, c.y_test)

# %%
f.features_selection()
# Out:
# Shape of X: (623, 29)
#
# Processing features selection based on the population stability index PSI...
# 11 - feature was filtered
#
# Shape of X: (623, 18)
#
# Processing features selection by their importance...
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 239, number of negative: 384
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000102 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 429
# [LightGBM] [Info] Number of data points in the train set: 623, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.383628 -> initscore=-0.474179
# [LightGBM] [Info] Start training from score -0.474179
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
t = Training(f.X_train, f.X_val, f.X_test, f.y_train, f.y_val, f.y_test)

# %%
t.training_model()
# Out:
# Processing training model and hyperparameter selection...
# starting ROC-AUC:
# train: 1.0
# val: 0.8737922705314008
# test: 0.7903225806451613
#
# Best Parameters: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100, 'num_leaves': 3}
#
# finishing ROC-AUC:
# train: 0.8577514818688982
# val: 0.8913043478260868
# test: 0.7541935483870968
#
# Processing of saving the model...
# path: model_LGBMClassifier.pkl
#
# Processing of saving the features...
# path: features_model_LGBMClassifier.csv
