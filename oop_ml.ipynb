# %% [markdown]
# # Data Processing and Modeling Pipeline

# %%
from pipeline.pipeline import Pipeline

# %% [markdown]
# ## Test 1

# %%
p = Pipeline(
    path='data/dataset1.csv',
    target_name='Survived'    
    )

# %%
p.clean()
# Out:
# Shape of dataset: (891, 11)
#
# Removing duplicates...
# 0 - strings was filtered
#
# Separating features by type...
# numeric_features: 7
# object_features: 3
# bool_features: 1
#
# Removing features with high mutual correlation...
# removed futures with high correlation: set()
# Shape of dataset: (891, 11)
#
# Preprocessing encoding object features...
# data types in the dataset: [dtype('int64') dtype('float64') dtype('bool')]
#
# Splitting dataset into training, testing and validation...
# Shape of:
# X_train: (623, 29), X_val_test: (268, 29)
# X_val: (187, 29), X_test: (81, 29)
#
# Processing nan value by k-nearest neighbors method...
# number of nan values in dataset: 0

# %%
p.features()
# Out:
# Shape of X: (623, 29)
#
# Processing features selection based on the population stability index PSI...
# 11 - feature was filtered
#
# Shape of X: (623, 18)
#
# Processing features selection by their importance...
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 239, number of negative: 384
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000104 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 429
# [LightGBM] [Info] Number of data points in the train set: 623, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.383628 -> initscore=-0.474179
# [LightGBM] [Info] Start training from score -0.474179
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
p.training()
# Out:
# Processing training model and hyperparameter selection...
# starting ROC-AUC:
# train: 1.0
# val: 0.87
# test: 0.79
#
# Best Parameters: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100, 'num_leaves': 3}
#
# finishing ROC-AUC:
# train: 0.86
# val: 0.89
# test: 0.75
#
# Processing of saving the model...
# path: model_LGBMClassifier.pkl
#
# Processing of saving the features...
# path: features_model_LGBMClassifier.csv

# %% [markdown]
# ### Model metrics

# %% [markdown]
# #### starting ROC-AUC:
# - train: 1.0
# - val: 0.87
# - test: 0.79
#
# Best Parameters: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100, 'num_leaves': 3}
#
# #### finishing ROC-AUC:
# - train: 0.86
# - val: 0.89
# - test: 0.75

# %% [markdown]
# ## Test 2

# %%
p = Pipeline(
    path='data/dataset2.csv',
    target_name='Survived'    
    )

# %%
p.clean()
# Out:
# Shape of dataset: (891, 12)
#
# Removing duplicates...
# 0 - strings was filtered
#
# Separating features by type...
# numeric_features: 7
# object_features: 5
# bool_features: 0
#
# Removing features with high mutual correlation...
# removed futures with high correlation: set()
# Shape of dataset: (891, 12)
#
# Preprocessing encoding object features...
# data types in the dataset: [dtype('int64') dtype('float64') dtype('bool')]
#
# Splitting dataset into training, testing and validation...
# Shape of:
# X_train: (623, 1730), X_val_test: (268, 1730)
# X_val: (187, 1730), X_test: (81, 1730)
#
# Processing nan value by k-nearest neighbors method...
# number of nan values in dataset: 0

# %%
p.features()
# Out:
# Shape of X: (623, 1730)
#
# Processing features selection based on the population stability index PSI...
# 1254 - feature was filtered
#
# Shape of X: (623, 476)
#
# Processing features selection by their importance...
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 239, number of negative: 384
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000102 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 421
# [LightGBM] [Info] Number of data points in the train set: 623, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.383628 -> initscore=-0.474179
# [LightGBM] [Info] Start training from score -0.474179
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
p.training()
# Out:
# Processing training model and hyperparameter selection...
# starting ROC-AUC:
# train: 1.0
# val: 0.83
# test: 0.78
#
# Best Parameters: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 5, 'num_leaves': 5}
#
# finishing ROC-AUC:
# train: 0.85
# val: 0.86
# test: 0.79
#
# Processing of saving the model...
# path: model_LGBMClassifier.pkl
#
# Processing of saving the features...
# path: features_model_LGBMClassifier.csv

# %% [markdown]
# ### Model metrics

# %% [markdown]
# #### starting ROC-AUC:
# - train: 1.0
# - val: 0.83
# - test: 0.78
#
# Best Parameters: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100, 'num_leaves': 3}
#
# #### finishing ROC-AUC:
# - train: 0.85
# - val: 0.86
# - test: 0.79

# %% [markdown]
# ## Test 3

# %%
p = Pipeline(
    path='data/dataset3.csv',
    target_name='class',
    encoding_method='target_encoding'
    )

# %%
p.clean()
# Out:
# Shape of dataset: (5000, 21)
#
# Removing duplicates...
# 0 - strings was filtered
#
# Separating features by type...
# numeric_features: 21
# object_features: 0
# bool_features: 0
#
# Removing features with high mutual correlation...
# removed futures with high correlation: {'total_night_minutes', 'total_day_minutes', 'number_vmail_messages', 'total_eve_charge', 'total_intl_minutes'}
# Shape of dataset: (5000, 16)
#
# Splitting dataset into training, testing and validation...
# Shape of:
# X_train: (3500, 15), X_val_test: (1500, 15)
# X_val: (1050, 15), X_test: (450, 15)
#
# Preprocessing encoding object features...
# data types in the dataset:
# X_train: [dtype('int64') dtype('float64')]
# X_val: [dtype('int64') dtype('float64')]
# X_test: [dtype('int64') dtype('float64')]
#
# Processing nan value by k-nearest neighbors method...
# number of nan values in dataset: 0

# %%
p.features()
# Out:
# Shape of X: (3500, 15)
#
# Processing features selection based on the population stability index PSI...
# 1 - feature was filtered
#
# Shape of X: (3500, 14)
#
# Processing features selection by their importance...
# [LightGBM] [Info] Number of positive: 495, number of negative: 3005
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000421 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1780
# [LightGBM] [Info] Number of data points in the train set: 3500, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.141429 -> initscore=-1.803475
# [LightGBM] [Info] Start training from score -1.803475
#  98%|===================| 3438/3500 [00:14<00:00]
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
p.training()
# Out:
# Processing training model and hyperparameter selection...
# starting ROC-AUC:
# train: 1.0
# val: 0.87
# test: 0.85
#
# Best Parameters: {'learning_rate': 0.2, 'max_depth': -1, 'n_estimators': 5, 'num_leaves': 10}
#
# finishing ROC-AUC:
# train: 0.87
# val: 0.9
# test: 0.86
#
# Processing of saving the model...
# path: model_LGBMClassifier.pkl
#
# Processing of saving the features...
# path: features_model_LGBMClassifier.csv

# %% [markdown]
# ### Model metrics

# %% [markdown]
# #### starting ROC-AUC:
# - train: 1.0
# - val: 0.87
# - test: 0.85
#
# Best Parameters: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100, 'num_leaves': 3}
#
# #### finishing ROC-AUC:
# - train: 0.87
# - val: 0.90
# - test: 0.86

# %%
#pip freeze >> requirements.txt
